# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Описание-проекта" data-toc-modified-id="Описание-проекта-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Описание проекта</a></span></li><li><span><a href="#Описание-данных" data-toc-modified-id="Описание-данных-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Описание данных</a></span></li><li><span><a href="#Загрузка-датасетов,-вывод-данных-для-первичного-анализа" data-toc-modified-id="Загрузка-датасетов,-вывод-данных-для-первичного-анализа-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Загрузка датасетов, вывод данных для первичного анализа</a></span><ul class="toc-item"><li><span><a href="#Предварительный-анализ-загруженных-данных" data-toc-modified-id="Предварительный-анализ-загруженных-данных-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Предварительный анализ загруженных данных</a></span></li><li><span><a href="#Анализ-данных-таблицы-data_arc" data-toc-modified-id="Анализ-данных-таблицы-data_arc-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Анализ данных таблицы data_arc</a></span></li><li><span><a href="#Анализ-данных-таблицы-data_temp" data-toc-modified-id="Анализ-данных-таблицы-data_temp-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Анализ данных таблицы data_temp</a></span></li><li><span><a href="#Анализ-данных-таблицы-data_bulk-и-data_wire" data-toc-modified-id="Анализ-данных-таблицы-data_bulk-и-data_wire-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>Анализ данных таблицы data_bulk и data_wire</a></span></li><li><span><a href="#Вывод-в-рамках-первичного-анализа" data-toc-modified-id="Вывод-в-рамках-первичного-анализа-3.5"><span class="toc-item-num">3.5&nbsp;&nbsp;</span>Вывод в рамках первичного анализа</a></span></li></ul></li><li><span><a href="#Формирование-датафрейма-с--признаками" data-toc-modified-id="Формирование-датафрейма-с--признаками-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Формирование датафрейма с  признаками</a></span></li><li><span><a href="#Проверка-на-корреляцию-между-сформированными-признаками" data-toc-modified-id="Проверка-на-корреляцию-между-сформированными-признаками-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Проверка на корреляцию между сформированными признаками</a></span></li><li><span><a href="#Формирование-целевого-признака" data-toc-modified-id="Формирование-целевого-признака-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Формирование целевого признака</a></span></li><li><span><a href="#Построение-модели" data-toc-modified-id="Построение-модели-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Построение модели</a></span><ul class="toc-item"><li><span><a href="#Формирование-тестовой-и-обучающей-выборки" data-toc-modified-id="Формирование-тестовой-и-обучающей-выборки-7.1"><span class="toc-item-num">7.1&nbsp;&nbsp;</span>Формирование тестовой и обучающей выборки</a></span></li><li><span><a href="#Формирование-списка-моделей-для-тестирования" data-toc-modified-id="Формирование-списка-моделей-для-тестирования-7.2"><span class="toc-item-num">7.2&nbsp;&nbsp;</span>Формирование списка моделей для тестирования</a></span></li><li><span><a href="#Оценка-полученных-значений-целевой-метрики-MAE" data-toc-modified-id="Оценка-полученных-значений-целевой-метрики-MAE-7.3"><span class="toc-item-num">7.3&nbsp;&nbsp;</span>Оценка полученных значений целевой метрики MAE</a></span></li><li><span><a href="#Оценка-адекватности-полученной-модели-(в-сравнении-с-фиктивной-моделью)" data-toc-modified-id="Оценка-адекватности-полученной-модели-(в-сравнении-с-фиктивной-моделью)-7.4"><span class="toc-item-num">7.4&nbsp;&nbsp;</span>Оценка адекватности полученной модели (в сравнении с фиктивной моделью)</a></span></li><li><span><a href="#Оценка-на-нормальность-распределения" data-toc-modified-id="Оценка-на-нормальность-распределения-7.5"><span class="toc-item-num">7.5&nbsp;&nbsp;</span>Оценка на нормальность распределения</a></span></li><li><span><a href="#Оценка-важности-признаков-в-прогнозе-модели" data-toc-modified-id="Оценка-важности-признаков-в-прогнозе-модели-7.6"><span class="toc-item-num">7.6&nbsp;&nbsp;</span>Оценка важности признаков в прогнозе модели</a></span></li></ul></li><li><span><a href="#Итоговый-вывод" data-toc-modified-id="Итоговый-вывод-8"><span class="toc-item-num">8&nbsp;&nbsp;</span>Итоговый вывод</a></span></li></ul></div>

# %% [markdown]
# ### Описание проекта

# %% [markdown]
# Требуется оптимизировать производственные расходы для металлургического комбината ООО «Так закаляем сталь» путем уменьшения потребление электроэнергии на этапе обработки стали.
# **Необходимо построить модель, которая предскажет температуру стали.**

# %% [markdown]
# Сталь обрабатывают в металлическом ковше вместимостью около 100 тонн. Чтобы ковш выдерживал высокие температуры, изнутри его облицовывают огнеупорным кирпичом. Расплавленную сталь заливают в ковш и подогревают до нужной температуры графитовыми электродами. Они установлены в крышке ковша.
#
# Из сплава выводится сера (десульфурация), добавлением примесей корректируется химический состав и отбираются пробы. Сталь легируют — изменяют её состав — подавая куски сплава из бункера для сыпучих материалов или проволоку через специальный трайб-аппарат (англ. tribe, «масса»).
#
# Перед тем как первый раз ввести легирующие добавки, измеряют температуру стали и производят её химический анализ. Потом температуру на несколько минут повышают, добавляют легирующие материалы и продувают сплав инертным газом. Затем его перемешивают и снова проводят измерения. Такой цикл повторяется до достижения целевого химического состава и оптимальной температуры плавки.
#
# Тогда расплавленная сталь отправляется на доводку металла или поступает в машину непрерывной разливки. Оттуда готовый продукт выходит в виде заготовок-слябов (англ. *slab*, «плита»).

# %% [markdown]
# ### Описание данных
#
# Данные состоят из файлов, полученных из разных источников:
#
# - `data_arc.csv` — данные об электродах;
# - `data_bulk.csv` — данные о подаче сыпучих материалов (объём);
# - `data_bulk_time.csv` *—* данные о подаче сыпучих материалов (время);
# - `data_gas.csv` — данные о продувке сплава газом;
# - `data_temp.csv` — результаты измерения температуры;
# - `data_wire.csv` — данные о проволочных материалах (объём);
# - `data_wire_time.csv` — данные о проволочных материалах (время).
#
# Во всех файлах столбец `key` содержит номер партии. В файлах может быть несколько строк с одинаковым значением `key`: они соответствуют разным итерациям обработки.

# %% [markdown]
# ### Загрузка датасетов, вывод данных для первичного анализа

# %%
pip install cufflinks
# Out:
# ...
#      |████████████████████████████████| 81 kB 2.6 MB/s eta 0:00:011
# ...
#   Created wheel for cufflinks: filename=cufflinks-0.17.3-py3-none-any.whl size=67922 sha256=692158c58253dd53f6c174523724c2ca29cc564d2a23322eff4371dc167989dc
#   Stored in directory: /home/jovyan/.cache/pip/wheels/29/b4/f8/2fd2206eeeba6ccad8167e4e8894b8c4ec27bf1342037fd136
# Successfully built cufflinks
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import datetime

from pathlib import Path
from sklearn.metrics import mean_absolute_error, mean_squared_error, median_absolute_error
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

from catboost import CatBoostRegressor
from sklearn.dummy import DummyRegressor
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from lightgbm import LGBMRegressor, plot_importance


# для визуализации
import cufflinks as cf
from plotly.offline import iplot #download_plotlyjs, init_notebook_mode, plot, 
cf.set_config_file(sharing='public',theme='ggplot',offline=True)
#import shap
from sklearn.inspection import permutation_importance
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.6.3.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
# выгрузим все датафреймы
try:
    data_arc = pd.read_csv('/datasets/final_steel/data_arc.csv') #данные об электродах, ЭТО БУДЕТ ОСНОВНАЯ ТАБЛИЦА.
    data_bulk = pd.read_csv('/datasets/final_steel/data_bulk.csv') #данные о подаче сыпучих материалов (объём)
    data_bulk_time = pd.read_csv('/datasets/final_steel/data_bulk_time.csv') # данные о подаче сыпучих материалов (время)
    data_gas = pd.read_csv('/datasets/final_steel/data_gas.csv') # данные о продувке сплава газом
    data_temp = pd.read_csv('/datasets/final_steel/data_temp.csv') # результаты измерения температуры
    data_wire = pd.read_csv('/datasets/final_steel/data_wire.csv') # данные о проволочных материалах (объём)
    data_wire_time = pd.read_csv('/datasets/final_steel/data_arc.csv') # данные о проволочных материалах (время)
except FileNotFoundError:
    print('Ошибка чтения файлов (одного из файлов), проверьте местоположение/название файлов(-а)!')
# Out:
# Ошибка чтения файлов (одного из файлов), проверьте местоположение/название файлов(-а)!

# %%
# создадим словарь  - название файла и его описание
dict_file = {'data_arc': 'Нагрев электродов', 
                  'data_bulk': 'Подача сыпучих материалов (объём)',
                  'data_bulk_time': 'Подача сыпучих материалов (время)',
                  'data_gas': 'Продувка сплава газом',
                  'data_temp': 'Результат измерения температуры',    
                  'data_wire': 'Подача проволочных материалов (объем)',
                  'data_wire_time': 'Подача проволочных материалов (время)'}

# %%
# Здесь, для первичного анализа данных немного оптимизируем выгрузку
path = '/datasets/final_steel/'
file_dir = Path(path)

table_file = {}
for file in file_dir.glob('*.csv'):
    file_name = file.parts[-1].split('.')[0]
    table_file[file_name] = pd.read_csv(file)

# %%
k=0
for data in dict_file.keys():
    print (f' Датафрейм: {dict_file[data]} (файл данных: {list(dict_file.keys())[k]}.cvs)')
    
    print ('\nРазмерность датасета:', table_file[data].shape)
    print ('Пропуски:\n', table_file[data].isnull().sum())
    print ('\nДубликаты:',table_file[data].duplicated().sum())
    
    print ('\nВывод первых 5ти записей таблицы:')
    display(table_file[data].head())
    print (' Анализ данных методом info()\n')
    display (table_file[data].info())
    print('_________        _________          _________\n')
    print ('Анализ данных методом describe()')
    display (table_file[data].describe())
    print('\n***********************************************************************************************\n')
    k +=1
# Out:
#  Датафрейм: Нагрев электродов (файл данных: data_arc.cvs)
#
# Размерность датасета: (14876, 5)
# Пропуски:
#  key                     0
# Начало нагрева дугой    0
# Конец нагрева дугой     0
# Активная мощность       0
# Реактивная мощность     0
# dtype: int64
#
# Дубликаты: 0
#
# Вывод первых 5ти записей таблицы:
#    key Начало нагрева дугой  Конец нагрева дугой  Активная мощность  \
# 0    1  2019-05-03 11:02:14  2019-05-03 11:06:02           0.976059
# 1    1  2019-05-03 11:07:28  2019-05-03 11:10:33           0.805607
# 2    1  2019-05-03 11:11:44  2019-05-03 11:14:36           0.744363
# 3    1  2019-05-03 11:18:14  2019-05-03 11:24:19           1.659363
# 4    1  2019-05-03 11:26:09  2019-05-03 11:28:37           0.692755
#
#    Реактивная мощность
# 0             0.687084
# 1             0.520285
# 2             0.498805
# 3             1.062669
# 4             0.414397
#  Анализ данных методом info()
#
# <class 'pandas.core.frame.DataFrame'>
# ...

# %% [markdown]
# #### Предварительный анализ загруженных данных

# %% [markdown]
# Все таблицы данных  имеют разную размерность, но все они связаны между собой по номеру партии/"варки" (key).
# Ряд таблиц содержат более подробную информацию в рамках каждой "варки", есть несколько замеров температур в рамках одной "варки".
# Присутствуют как пропуски данных, так и сами "варки":
#
# Кол-во "варок" после объединения по key(партия, она же "варка") - 3214
# Между тем последний порядковый номер key = 3241, т.е. отсутвуют данные по 27 варкам, менее 1%, от объема, что не критично.
#
# Сыпучие присадки использовались в 3129 варках.
# Присадка метал.провол. использовалась в 3081 варке.
# Газ - 3239
#
# Есть большое кол-во пропусков для таблиц data_bulk и data_wire в дальнейшем заменим пропуски нулями (что логично: есть присадка - есть какой то ее объем, нет присадки - ноль), плюс удалим практически не используемые "присадки".
#
# Есть два датафрейма: data_bulk_time и data_wire_time, которые в дальнейшем не будут использоваться.
#
#
# Приведем название столбцов к общепринятому формату.

# %%
data_arc[data_arc['Реактивная мощность']<0] # единичный случай, спишем на сбой, данную запись в последующим - удалим.
# Out:
#        key Начало нагрева дугой  Конец нагрева дугой  Активная мощность  \
# 9780  2116  2019-07-24 00:44:48  2019-07-24 00:46:37           0.495782
#
#       Реактивная мощность
# 9780          -715.504924

# %% [markdown]
# **Приведем название столбцов к общепринятому формату**

# %%
data_arc.rename(columns={'Начало нагрева дугой': 'start_time_heat', 
                         'Конец нагрева дугой': 'stop_time_heat',
                         'Активная мощность': 'active_power',
                         'Реактивная мощность': 'reactive_power'}, inplace=True)

# %%
data_arc.columns
# Out:
# Index(['key', 'start_time_heat', 'stop_time_heat', 'active_power',
#        'reactive_power'],
#       dtype='object')

# %%
data_temp.rename(columns={'Время замера': 'time_sample',
                         'Температура': 'temperature'}, inplace=True)

# %%
data_bulk.rename(columns=lambda x: x.replace(' ', '_'), inplace=True)
data_bulk.rename(columns=lambda x: x.lower(), inplace=True)

# %%
data_wire.rename(columns=lambda x: x.replace(' ', '_'), inplace=True)
data_wire.rename(columns=lambda x: x.lower(), inplace=True)

# %%
data_gas.rename(columns={'Газ 1': 'gas'}, inplace=True)

# %% [markdown]
# Сформирую столбец с количеством секунд работы этектродов в течение "варки" , сформирую столбец с полной мощность потребления.(инфу формирую для себя, если будет не востребована, то в дальнейшем удалю)

# %%
t1 = pd.to_datetime(data_arc['stop_time_heat'])
t2 = pd.to_datetime(data_arc['start_time_heat'])

# %%
data_arc['time_work_heat']=(t1-t2).astype('timedelta64[s]')

# %%
data_arc['full_power']=(data_arc['active_power']**2+data_arc['reactive_power']**2)**0.5

# %%
data_arc.tail(6)
# Out:
#         key      start_time_heat       stop_time_heat  active_power  \
# 14870  3240  2019-09-01 03:31:47  2019-09-01 03:34:08      0.548882
# 14871  3241  2019-09-01 03:58:58  2019-09-01 04:01:35      0.533670
# 14872  3241  2019-09-01 04:05:04  2019-09-01 04:08:04      0.676604
# 14873  3241  2019-09-01 04:16:41  2019-09-01 04:19:45      0.733899
# 14874  3241  2019-09-01 04:31:51  2019-09-01 04:32:48      0.220694
# 14875  3241  2019-09-01 04:34:47  2019-09-01 04:36:08      0.306580
#
#        reactive_power  time_work_heat  full_power
# 14870        0.416994           141.0    0.689315
# 14871        0.354439           157.0    0.640648
# 14872        0.523631           180.0    0.855559
# 14873        0.475654           184.0    0.874560
# 14874        0.145768            57.0    0.264489
# 14875        0.196708            81.0    0.364260

# %%
# создаю временный столбец, по которому запущу в дальнейшем счетчик - Число итераций нагрева
data_arc['tmp']=data_arc['active_power']

# %%
# создаю сводную таблицу, которую в дальнейшем объеденю со сводной таблицей температур, для графической визуализации
data_arc_pivot = data_arc.pivot_table(index=['key'], 
                                          values=['active_power','reactive_power',
                                                  'time_work_heat','full_power','tmp'],
                                          aggfunc={'active_power': 'sum',
                                                   'reactive_power': 'sum',
                                                   'time_work_heat': 'sum',
                                                   'full_power': 'sum',
                                                   'tmp': 'count'})

data_arc_pivot.columns = ['sum_active_power','full_power',
                          'sum_reactive_power', 'total_time_work_heat', 
                          'count_iterat_heat']
data_arc_pivot.head(3)
# Out:
#      sum_active_power  full_power  sum_reactive_power  total_time_work_heat  \
# key
# 1            4.878147    5.826395            3.183241                1098.0
# 2            3.052598    3.649216            1.998112                 811.0
# 3            2.525882    2.989534            1.599076                 655.0
#
#      count_iterat_heat
# key
# 1                    5
# 2                    4
# 3                    5

# %%
#создаю сводную таблицу, чтобы в дальнейшем графически оценить кол-во замеров температуры на число итераций нагрева.
data_temp_pivot = data_temp.pivot_table(index=['key'],values=['temperature'],aggfunc='count')
data_temp_pivot.columns = ['count_sample_temperature']
data_temp_pivot.head(3)
# Out:
#      count_sample_temperature
# key
# 1                           5
# 2                           6
# 3                           5

# %%
# объединяю пару таблиц для графического анализа
merge_arc_temp_pivot = data_arc_pivot.merge(data_temp_pivot,on='key')
merge_arc_temp_pivot.head(3)
# Out:
#      sum_active_power  full_power  sum_reactive_power  total_time_work_heat  \
# key
# 1            4.878147    5.826395            3.183241                1098.0
# 2            3.052598    3.649216            1.998112                 811.0
# 3            2.525882    2.989534            1.599076                 655.0
#
#      count_iterat_heat  count_sample_temperature
# key
# 1                    5                         5
# 2                    4                         6
# 3                    5                         5

# %% [markdown]
# #### Анализ данных таблицы data_arc

# %%
merge_arc_temp_pivot[['count_iterat_heat','count_sample_temperature']].iplot(kind='hist', yTitle='Число таких "варок"',
                           xTitle='Число итераций нагрева/замеров температур ("на варку")')
# Out:
# <div>                            <div id="7b372355-7b5f-4970-836b-cf94d7bd544b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %% [markdown]
# Гистограмма хорошо демонстрирует различие в числе температурных замеров и числе итераций нагрева на варку.
# Это или разгильдяйство, или потеря данных(не работал термометр/датчик температуры).
# В моем понимании, после каждой присадки необходим замер хим. состава и температуры, иначе ввод на "глазок" присадок увеличивает длительность варки (получение необходимого состава стали), а это чревато перерасходом энергии.

# %% [markdown]
# Учитывая предположение, что нам нужны как минимум ДВА замера температуры: начальная температура и конечная (финишная) которая будет в дальнейшем целью нашего исследования, удалим из таблицы data_temp, "варки" с одним замером температуры.
# Да, чистка получается довольно жесткой, почти 25% данных по замерам температур, а значит и всех остальных (т.к. таблицы будут связывать пономеру "варки") пойдут в корзину, но пока исследование это, я вижу так.

# %%
# формируем список индексов варок, где был всего 1 замер температуры
list_one_temp = data_temp_pivot[data_temp_pivot['count_sample_temperature']==1].index
len(list_one_temp) # здесь оцениваю "маштаб бедствия"
# Out:
# 741

# %%
# формируем датасет без единичного замера температуры
data_temp = data_temp.query('key not in @list_one_temp')

# %% [markdown]
# **КСТАТИ, а теперь число итераций нагрева, более менее соответсвует числу замеров температур!**

# %%
data_temp_pivot = data_temp.pivot_table(index=['key'],values=['temperature'],aggfunc='count')
data_temp_pivot.columns = ['count_sample_temperature']
merge_arc_temp_pivot = data_arc_pivot.merge(data_temp_pivot,on='key')
merge_arc_temp_pivot[['count_iterat_heat','count_sample_temperature']].iplot(kind='hist', yTitle='Число таких "варок"',
                           xTitle='Число итераций нагрева/замеров температур ("на варку")')
# Out:
# <div>                            <div id="e84306e7-d37a-416c-9929-ff1a44ab97ec" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %% [markdown]
# #### Анализ данных таблицы data_temp

# %% [markdown]
# **Посмотрим, что по температурным выбросам:**

# %%
data_temp.describe()
# Out:
#                 key   temperature
# count  12265.000000  12265.000000
# mean    1235.751896   1591.998859
# std      729.400276     20.834479
# min        1.000000   1191.000000
# 25%      602.000000   1581.000000
# 50%     1239.000000   1591.000000
# 75%     1874.000000   1601.000000
# max     2499.000000   1705.000000

# %%
data_temp['temperature'].iplot(kind='hist', xTitle='Температура', yTitle='Частота')
# Out:
# <div>                            <div id="1aa6a6f4-6ab5-413b-8ee6-924fe4a12c99" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %% [markdown]
# Немного "укрупним" график, соберем замеры температур каждой варки. Возьмем среднее значение.

# %%
temp_pivot = data_temp.pivot_table(index=['key'],values=['temperature'],aggfunc='mean')
temp_pivot['temperature'].iplot(kind='hist', xTitle='Средняя температура "варки"',
                           yTitle='Число таких "варок"')
# Out:
# <div>                            <div id="9739fd40-a099-4cdb-9b23-7dc875a2c93d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %% [markdown]
# Визуализируем немного по другому...

# %%
sns.set(rc={'figure.figsize':(10,5)})
sns.boxplot(data=temp_pivot)
plt.title('Боксплот распределения температур в "варках"')
plt.show()

# %%
temp_pivot.describe()
# Out:
#        temperature
# count  2475.000000
# mean   1591.368557
# std      16.316032
# min    1518.400000
# 25%    1581.708333
# 50%    1590.000000
# 75%    1598.444444
# max    1681.800000

# %% [markdown]
# Как видим, основной "рабочий" диапазон плавления стали в диапазоне от 1555 до 1625 градусов. Все "варки", в которых температура менее 1555 градусов  и более 1625 удалим как выбросы.

# %% [markdown]
# **Вытащим индексы этих выбивающихся из нормы температур**
# В дальнейшем, данные с этими индексами будут удалены

# %%
list_min_temp = temp_pivot[temp_pivot['temperature']<1555].index
list_min_temp
# Out:
# Int64Index([867, 1186, 1362, 1503, 1504, 1599, 1619, 1671, 1672, 1948, 2052,
#             2419],
#            dtype='int64', name='key')

# %%
temp_pivot[temp_pivot['temperature']>1625].count()
# Out:
# temperature    86
# dtype: int64

# %%
list_max_temp = temp_pivot[temp_pivot['temperature']>1625].index

# %% [markdown]
# #### Анализ данных таблицы data_bulk и data_wire

# %% [markdown]
# **Оценим востребованность различных видов "присадок"**

# %%
# сыпучих
data_bulk.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3129 entries, 0 to 3128
# Data columns (total 16 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   key      3129 non-null   int64
#  1   bulk_1   252 non-null    float64
#  2   bulk_2   22 non-null     float64
#  3   bulk_3   1298 non-null   float64
#  4   bulk_4   1014 non-null   float64
#  5   bulk_5   77 non-null     float64
#  6   bulk_6   576 non-null    float64
#  7   bulk_7   25 non-null     float64
#  8   bulk_8   1 non-null      float64
#  9   bulk_9   19 non-null     float64
#  10  bulk_10  176 non-null    float64
#  11  bulk_11  177 non-null    float64
#  12  bulk_12  2450 non-null   float64
#  13  bulk_13  18 non-null     float64
#  14  bulk_14  2806 non-null   float64
#  15  bulk_15  2248 non-null   float64
# dtypes: float64(15), int64(1)
# memory usage: 391.2 KB

# %% [markdown]
# Дропнем столбцы где присадку применяли менее 1% от числа "варок", это:
# Bulk 2,  Bulk 7, Bulk 8, Bulk 9, Bulk 13.
# Заполним пропуски нулями.

# %%
data_bulk = data_bulk.drop(['bulk_2', 'bulk_7', 'bulk_8', 'bulk_9', 'bulk_13'], axis=1)
data_bulk=data_bulk.fillna(0)

# %%
# проволоки
data_wire.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3081 entries, 0 to 3080
# Data columns (total 10 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   key     3081 non-null   int64
#  1   wire_1  3055 non-null   float64
#  2   wire_2  1079 non-null   float64
#  3   wire_3  63 non-null     float64
#  4   wire_4  14 non-null     float64
#  5   wire_5  1 non-null      float64
#  6   wire_6  73 non-null     float64
#  7   wire_7  11 non-null     float64
#  8   wire_8  19 non-null     float64
#  9   wire_9  29 non-null     float64
# dtypes: float64(9), int64(1)
# memory usage: 240.8 KB

# %% [markdown]
# здесь так же по аналогии, дропнем столбцы Wire 4,Wire 5,  Wire 7 и Wire 8.

# %%
data_wire = data_wire.drop(['wire_4', 'wire_5', 'wire_7', 'wire_8'], axis=1)
data_wire=data_wire.fillna(0)

# %% [markdown]
# #### Вывод в рамках первичного анализа

# %% [markdown]
# Таблицы с данными попались "разношерстные" - имеющие разную размерность но объединенные единым параметром/ключем - key.
# Обнаруженные пропуски в таблицах "присадок" были заменены на ноль. Сами таблицы присадок были сжаты за счет удаления незначимых типов присадок, число применения которых составило менее 1 %.
# Таблица замеров температур на варку, так же была подчищина, были удалены "варки" с излишне низкими или высокими температурами.
# Первичный анализ помог сформировать более детальный план дальнейших действий, а именно помог понять какие признаки пойдут в "фичи", а какой в целевой. В преамбуле к данной работе, описан процесс становления модели ).

# %% [markdown]
# **Теперь реализуем план действий**

# %% [markdown]
# ### Формирование датафрейма с  признаками

# %% [markdown]
# **Объем данных целевого признака должен соответвовать объему фичь, поэтому приведем объемы "варок" в разных таблицах к единому размеру. Главный ключ соответствия - key (ключ) он же номер "варки"**

# %%
# создали список индексов на исключение из данных, где температура "варки" сильно отличается от нормальной (выброс)
list_tmp = list_one_temp.append(list_min_temp)
list_total=list_tmp.append(list_max_temp)

# %%
data_arc_pivot = data_arc_pivot.query('key not in @list_total')

# %%
data_arc_pivot.shape
# Out:
# (2377, 5)

# %% [markdown]
# **Чистим по итерациям, отрицательным значениям**

# %%
data_arc_iter = data_arc_pivot[((data_arc_pivot['count_iterat_heat']>1) & 
                                 (data_arc_pivot['count_iterat_heat']<8)) &
                                 (data_arc_pivot['sum_reactive_power']>0)]

# %%
data_arc_iter.shape
# Out:
# (2243, 5)

# %%
# получаем обновленный список индексов варок, чтобы в дальнейшем обновить список целевого признака.
list_new_key = data_arc_iter.index

# %%
data_temp.head(6)
# Out:
#    key          time_sample  temperature
# 0    1  2019-05-03 11:16:18       1571.0
# 1    1  2019-05-03 11:25:53       1604.0
# 2    1  2019-05-03 11:29:11       1618.0
# 3    1  2019-05-03 11:30:01       1601.0
# 4    1  2019-05-03 11:30:39       1613.0
# 5    2  2019-05-03 11:37:27       1581.0

# %%
# через сводную таблицу, вытаскиваю первый и последний замер температуры для каждой варки
temp_start = data_temp.pivot_table(index=['key'],values='time_sample',
                                         aggfunc={'time_sample':'min'})

temp_finish = data_temp.pivot_table(index=['key'],values='time_sample',
                                         aggfunc={'time_sample':'max'})

# %%
# создаю по сути временную таблицу с временнЫми данными на начальную температуру (первый замером)
temp_start = temp_start.query('key  in @list_new_key')

# %%
temp_start.head(2)
# Out:
#              time_sample
# key
# 1    2019-05-03 11:16:18
# 2    2019-05-03 11:37:27

# %% [markdown]
# **Формируем таблицу с начальной температурой для каждой варки, для последующего объединения с основной таблице**

# %%
data_temp_start = data_temp.merge(temp_start,on='time_sample')
data_temp_start.head(3)
# Out:
#    key          time_sample  temperature
# 0    1  2019-05-03 11:16:18       1571.0
# 1    2  2019-05-03 11:37:27       1581.0
# 2    3  2019-05-03 12:13:17       1596.0

# %%
# соберем таблицы и вытащим температуру первого замера (столбец time_sample позже удалим)
merge_arc_temp_start = data_arc_iter.merge(data_temp_start, on = 'key' )

# %%
merge_arc_temp_start.head(3)
# Out:
#    key  sum_active_power  full_power  sum_reactive_power  \
# 0    1          4.878147    5.826395            3.183241
# 1    2          3.052598    3.649216            1.998112
# 2    3          2.525882    2.989534            1.599076
#
#    total_time_work_heat  count_iterat_heat          time_sample  temperature
# 0                1098.0                  5  2019-05-03 11:16:18       1571.0
# 1                 811.0                  4  2019-05-03 11:37:27       1581.0
# 2                 655.0                  5  2019-05-03 12:13:17       1596.0

# %%
merge_arc_temp_start.shape
# Out:
# (2243, 8)

# %%
# ну а теперь самое "вкусное" - соберем таблицу фичь, она опять немного "похудеет", 
# выпадают варки которых нет во всех 4-х собираемых таблицах
features = merge_arc_temp_start.merge(data_bulk, on='key').merge(data_wire, on='key').merge(data_gas, on='key')
features.shape
# Out:
# (2180, 24)

# %%
# смотрим, что получилось
features.head(3)
# Out:
#    key  sum_active_power  full_power  sum_reactive_power  \
# 0    1          4.878147    5.826395            3.183241
# 1    2          3.052598    3.649216            1.998112
# 2    3          2.525882    2.989534            1.599076
#
#    total_time_work_heat  count_iterat_heat          time_sample  temperature  \
# 0                1098.0                  5  2019-05-03 11:16:18       1571.0
# 1                 811.0                  4  2019-05-03 11:37:27       1581.0
# 2                 655.0                  5  2019-05-03 12:13:17       1596.0
#
#    bulk_1  bulk_3  ...  bulk_11  bulk_12  bulk_14  bulk_15     wire_1  wire_2  \
# 0     0.0     0.0  ...      0.0    206.0    150.0    154.0  60.059998     0.0
# 1     0.0     0.0  ...      0.0    206.0    149.0    154.0  96.052315     0.0
# 2     0.0     0.0  ...      0.0    205.0    152.0    153.0  91.160157     0.0
#
#    wire_3  wire_6  wire_9        gas
# 0     0.0     0.0     0.0  29.749986
# ...

# %%
list_keys = list(features['key'].unique())

# %% [markdown]
# ### Проверка на корреляцию между сформированными признаками

# %% [markdown]
# **Проверим корреляцию между этими фичами, реализуем это графически**

# %%
sns.set(rc = {'figure.figsize':(20,10)})
heatmap = sns.heatmap(features.corr(),vmin=0, vmax=1, annot=True, cmap='BrBG',fmt='.1g');
heatmap.set_title('Тепловая карта корреляции признаков', fontdict={'fontsize':24}, pad=15);
plt.xticks(rotation=45, ha='right');

# %% [markdown]
# Есть сильная зависимость между 'sum_active_power','sum_reactive_power' и total_time_work_heat.
# Удалим пару признаков, плюс пару не используемых.

# %%
features = features.drop(['sum_active_power','sum_reactive_power','total_time_work_heat','time_sample','key'], axis=1)

# %%
sns.set(rc = {'figure.figsize':(20,10)})
heatmap = sns.heatmap(features.corr(),vmin=0, vmax=1, annot=True, cmap='BrBG',fmt='.1g');
heatmap.set_title('Тепловая карта корреляции признаков', fontdict={'fontsize':24}, pad=15);
plt.xticks(rotation=45, ha='right');

# %% [markdown]
# **Ну вот, откровенных прямых зависимостей больше нет**

# %% [markdown]
# **Вернемся к целевой задачи:
# предсказать конечную температуру "стального бульона" на основании предшествующих введенных добавок/присадок и первичной температуры.**

# %% [markdown]
# ### Формирование целевого признака

# %%
# Формируем целевой признак
target = data_temp.merge(temp_finish,on='time_sample')
target.head(3)
# Out:
#    key          time_sample  temperature
# 0    1  2019-05-03 11:30:39       1613.0
# 1    2  2019-05-03 11:59:12       1602.0
# 2    3  2019-05-03 12:34:57       1599.0

# %%
target.shape
# Out:
# (2475, 3)

# %%
# очищаем его, оставляем только температуры для варок которые собраны в фичах.
target = target.query('key in @list_keys').drop(['key', 'time_sample'], axis=1)

# %%
target.shape
# Out:
# (2180, 1)

# %% [markdown]
# **Дело осталось за малым, разбить данные на выборки и применить разные алгоритмы.
# Алгоритм который покажет наименьшую метрику MAE и будет нашим "кумиром"! :).**

# %% [markdown]
# ### Построение модели

# %% [markdown]
# #### Формирование тестовой и обучающей выборки

# %%
# разбиваем данные на обучающую и тестовую выборку в соотношении 75/25
features_train, features_test, target_train, target_test = train_test_split(
    features, target, test_size=0.25, random_state=12345)

# %% [markdown]
# #### Формирование списка моделей для тестирования

# %%
models = []
models.append(('LR', LinearRegression())) 
models.append(('RF', RandomForestRegressor(random_state=12345))) 
models.append(('LGBMR', LGBMRegressor(random_state=12345)))
models.append(('CatBR', CatBoostRegressor(random_state=12345)))

# %%
mae_info = []
def model_best(features_train,target_train,features_test,target_test, models):
    
    for name, model in models:
        print ('\nМодель:',name)
        ml = model
        if name == 'CatBR':
            ml.fit(features_train, target_train, verbose=250)                
        else:
            ml.fit(features_train, target_train)
        predict = ml.predict(features_test)
        mae = mean_absolute_error(target_test, predict)
        print ('Значение метрики MAE на тестовой выборке:', round(mae,1))
        
        mae_info.append(round(mae,2))
        if name =='LGBMR':            
            plot_importance(ml)

# %% [markdown]
# #### Оценка полученных значений целевой метрики MAE

# %%
model_best(features_train,target_train,features_test,target_test, models)
# Out:
# Модель: LR
# Значение метрики MAE на тестовой выборке: 5.6
#
# Модель: RF
# /tmp/ipykernel_49/511164845.py:10: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
# Значение метрики MAE на тестовой выборке: 5.6
#
# Модель: LGBMR
# Значение метрики MAE на тестовой выборке: 5.6
#
# Модель: CatBR
# Learning rate set to 0.04425
# 0:	learn: 10.5243416	total: 50ms	remaining: 49.9s
# 250:	learn: 6.0323138	total: 710ms	remaining: 2.12s
# 500:	learn: 4.8703529	total: 1.39s	remaining: 1.38s
# 750:	learn: 4.1497500	total: 2.05s	remaining: 679ms
# 999:	learn: 3.5657456	total: 2.72s	remaining: 0us
# Значение метрики MAE на тестовой выборке: 5.4

# %% [markdown]
# Соберем результаты в таблицу

# %%
df = pd.DataFrame(mae_info, index=['LinearR', 'RandomForest', 'LGBMR', 'CatBoostR'], columns = ['MAE'])
df.sort_values(by='MAE')
# Out:
#                MAE
# CatBoostR     5.44
# RandomForest  5.59
# LinearR       5.62
# LGBMR         5.64

# %%
#from pyod.models.knn import KNN 
#model = KNN()
#model.fit(features_train, target_train)
#predictions = model.predict(features_test)
#predictions.sum()

# %% [markdown]
# #### Оценка адекватности полученной модели (в сравнении с фиктивной моделью)

# %% [markdown]
# Воспользуемся фиктивной моделью - DummyRegressor, и сравним полученные значения метрики MAE фиктивной модели и созданной CatBoostRegressor.

# %%
cat = CatBoostRegressor(random_state=12345).fit(features_train, target_train, verbose=250)

cat_dummy_mean = DummyRegressor(strategy = 'mean').fit(features_train, target_train)
cat_dummy_median = DummyRegressor(strategy = 'median').fit(features_train, target_train)

predict = cat.predict(features_test)
predict_train = cat.predict(features_train)

predict_dummy_mean = cat_dummy_mean.predict(features_test)
predict_dummy_median = cat_dummy_median.predict(features_test)
# Out:
# Learning rate set to 0.04425
# 0:	learn: 10.5243416	total: 3.71ms	remaining: 3.71s
# 250:	learn: 6.0323138	total: 666ms	remaining: 1.99s
# 500:	learn: 4.8703529	total: 1.3s	remaining: 1.3s
# 750:	learn: 4.1497500	total: 2.02s	remaining: 672ms
# 999:	learn: 3.5657456	total: 2.65s	remaining: 0us

# %%
print("Mean squared error (dummy): {:.2f}".format(mean_squared_error(target_test,predict_dummy_mean)))
print("Mean squared error (CatBR model): {:.2f}".format(mean_squared_error(target_test, predict)))
  
print("\nMean absolute error (dummy): {:.2f}".format(mean_absolute_error(target_test,predict_dummy_mean)))
print("Mean absolute error (CatBR model): {:.2f}".format(mean_absolute_error(target_test, predict)))
    
print("\nMedian absolute error (dummy): {:.2f}".format(median_absolute_error(target_test,predict_dummy_median)))
print("Median absolute error (CatBR model): {:.2f}".format(median_absolute_error(target_test,predict)))
# Out:
# Mean squared error (dummy): 102.16
# Mean squared error (CatBR model): 53.43
#
# Mean absolute error (dummy): 7.32
# Mean absolute error (CatBR model): 5.44
#
# Median absolute error (dummy): 5.00
# Median absolute error (CatBR model): 4.22

# %%
# попробую еще через константную модель, через "предсказанное" среднее значение
mean_temepature = np.array([int(target_test.mean())] * int(target_test.count()))
print ('Mean absolute error (const_mean):', round (mean_absolute_error(target_test, mean_temepature),2))
# Out:
# Mean absolute error (const_mean): 7.31

# %% [markdown]
# Как говориться: "почуствуюте разницу", Mean absolute error:
# Dummy: 7.32
# Const_mean: 7.31
# **CatBR model: 5.44**

# %% [markdown]
# Как видно, качество полученной модели по метрике Mean absolute error более чем на 30% выше чем фиктивной или константной модели.

# %% [markdown]
# #### Оценка на нормальность распределения

# %%
predict2 = pd.DataFrame(predict, index=target_test.index, columns = ['temperature'])
residual=target_test-predict2

# %%
plt.figure()
sns.displot(residual,kde=True)
plt.title("Оценка нормальности распределения значений ")
# Out:
# Text(0.5, 1.0, 'Оценка нормальности распределения значений ')

# %% [markdown]
# Остатки (от разности целевого и прогнозного значения) соответствуют нормальному распределению со средним значением 0. Это косвенно подтверждает корректность модели, нет аномальных прогнозов, либо они единичны.

# %%
predict_train = pd.DataFrame(predict_train, index =target_train.index, columns=['temperature'] )

# %%
plt.scatter(predict_train,  predict_train - target_train, c='blue', marker='o', label='Training data')
plt.scatter(predict2,  predict2 - target_test, c='lightgreen', marker='s', label='Test data')
plt.xlabel('Predicted values')
plt.ylabel('Residuals')
plt.legend(loc='upper left')
plt.xlim([1565, 1630])
plt.tight_layout()

# %% [markdown]
# Поскольку в нашей модели несколько независимых переменных, мы не можем отобразить их зависимость на двумерном пространстве, но можем нанести на график связь между остатками модели и предсказанными значениями, что также поможет нам диагностировать качество модели. Данный график/распределение поможет увидеть нелинейность и выбросы, проверить случайность распределения ошибки.

# %% [markdown]
# #### Оценка важности признаков в прогнозе модели

# %%
sorted_feature_importance = cat.feature_importances_.argsort()
plt.barh(features_test.columns[sorted_feature_importance], 
        cat.feature_importances_[sorted_feature_importance], 
        color='turquoise')
plt.xlabel("CatBoost Feature Importance");

# %% [markdown]
# Графическая визуализация важности признаков показало, что предположение о важности продувки инертным газом - имеет место.
# Газ, вошел в 5(пятерку!), самых важных фич. И если с присадками проволоки и сыпучки все понятно - wire_1 b bulk_14 самые часто используемые. То вот с Газом, до последнего графика, были сомнения.
# Признаки: Температура и Полная мощность довольно сильно коррелируют(выше мы показали это), и не удивительно, что здесь им отводиться ведущая роль, между тем удаление одного из эти признаков "как дублера", существенно снижает точность модели, именно поэтому я оставил их вместе.

# %% [markdown]
# ### Итоговый вывод

# %% [markdown]
# Обработав полученные первичные данные, удалось вычленить значимые параметры, работая в дальнейшем с которыми была построена модель на основе алогритма CatBoostRegressor с метрикой качества MAE равной 5.43-5.45.
# Данная модель позволит предсказывать конечную температуру партии стали на основе вводимых в варку присадок (как по типу так и по объему), объеме продувавемого инертного газа, начальной темперетуры "стального бульона", что позволит исключить излишний нагрев, а значит и сэкономит расходы на элетроэнергию металл.комбинату.
#
# Так же, хотелось бы отметить, что проводя иссленование, было отмечено отличие числа замеров темератур от числа итераций нагрева(числа ввода присадок), если это отличие обусловлено не технологическим регламентом, то требуется выяснить причину данного факта,т.к. фактически происходит внос присадок "на глазок", без контроля промежуточных значений (как по температуре, так и по хим. составу как я понимаю), а это чревато перерасходом как материала присадок так и повышенные расход электричества.

# %% [markdown]
# P.S.
# **Применение масштабирования и подбор гиперпараметров не сильно влияет на качество модели, улучшение метрики получаем всего 1-4 сотых, поэтому я не стал в основномном коде внедрять это"**

# %%
scaler = StandardScaler().fit(features_train)

features_train = scaler.transform(features_train)
features_test = scaler.transform(features_test)

# %%
cat = CatBoostRegressor(random_state=12345, loss_function="MAE", 
                        depth=3, iterations=500, learning_rate=0.1).fit(features_train, target_train, verbose=50)

predict = cat.predict(features_test)
print("Mean absolute error (CatBR model): {:.2f}".format(mean_absolute_error(target_test, predict)))
# Out:
# 0:	learn: 7.6251978	total: 1.33ms	remaining: 666ms
# 50:	learn: 5.8060068	total: 49.6ms	remaining: 436ms
# 100:	learn: 5.3992299	total: 94.7ms	remaining: 374ms
# 150:	learn: 5.1477692	total: 140ms	remaining: 324ms
# 200:	learn: 4.9433378	total: 186ms	remaining: 276ms
# 250:	learn: 4.8288006	total: 230ms	remaining: 228ms
# 300:	learn: 4.7171637	total: 276ms	remaining: 182ms
# 350:	learn: 4.6198161	total: 321ms	remaining: 136ms
# 400:	learn: 4.5487040	total: 368ms	remaining: 90.9ms
# 450:	learn: 4.4721905	total: 413ms	remaining: 44.8ms
# 499:	learn: 4.4056822	total: 456ms	remaining: 0us
# Mean absolute error (CatBR model): 5.43
